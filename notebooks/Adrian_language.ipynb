# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from langdetect import detect

# %%
from guess_language import guess_language

# %%
data_language_df = pd.read_csv("/home/adrian/code/federicoeramirez/jars/raw_data/data_lyrics_10k.csv")

# %%
data_language_df
# Out:
#       Unnamed: 0  valence  year  acousticness  \
# 0              0    0.817  2013      0.015800
# 1              1    0.548  2003      0.006610
# 2              2    0.732  2014      0.047700
# 3              3    0.475  1981      0.000473
# 4              4    0.550  1930      0.994000
# ...          ...      ...   ...           ...
# 9995        9995    0.726  2012      0.002240
# 9996        9996    0.834  1943      0.944000
# 9997        9997    0.902  1975      0.682000
# 9998        9998    0.896  1995      0.187000
# 9999        9999    0.218  2015      0.005540
#
#                                               artists  danceability  \
# 0                                        ['Parmalee']         0.551
# 1                                           ['JAY-Z']         0.494
# 2                                        ['Sam Hunt']         0.590
# 3                                     ['Iron Maiden']         0.340
# ...

# %% [markdown]
# # Detect language

# %% [markdown]
# ## First method (lyrics)

# %%
data_language_df["language"] = data_language_df["lyrics"].apply(detect)

# %%
data_language_df
# Out:
#       Unnamed: 0  valence  year  acousticness  \
# 0              0    0.817  2013      0.015800
# 1              1    0.548  2003      0.006610
# 2              2    0.732  2014      0.047700
# 3              3    0.475  1981      0.000473
# 4              4    0.550  1930      0.994000
# ...          ...      ...   ...           ...
# 9995        9995    0.726  2012      0.002240
# 9996        9996    0.834  1943      0.944000
# 9997        9997    0.902  1975      0.682000
# 9998        9998    0.896  1995      0.187000
# 9999        9999    0.218  2015      0.005540
#
#                                               artists  danceability  \
# 0                                        ['Parmalee']         0.551
# 1                                           ['JAY-Z']         0.494
# 2                                        ['Sam Hunt']         0.590
# 3                                     ['Iron Maiden']         0.340
# ...

# %%
data_language_df["language"].value_counts("en")*100
# Out:
# no    50.57
# en    42.55
# es     4.32
# it     1.42
# pt     0.34
# fr     0.25
# so     0.08
# de     0.07
# ja     0.07
# tl     0.05
# id     0.04
# et     0.03
# sk     0.03
# ko     0.03
# hi     0.02
# af     0.02
# tr     0.02
# sw     0.02
# sv     0.02
# el     0.01
# da     0.01
# fa     0.01
# ar     0.01
# ca     0.01
# Name: language, dtype: float64

# %% [markdown]
# ## Second method (name)

# %%
data_language_df["language_2"] = data_language_df["name"].apply(guess_language)

# %%
data_language_df
# Out:
#       Unnamed: 0  valence  year  acousticness  \
# 0              0    0.817  2013      0.015800
# 1              1    0.548  2003      0.006610
# 2              2    0.732  2014      0.047700
# 3              3    0.475  1981      0.000473
# 4              4    0.550  1930      0.994000
# ...          ...      ...   ...           ...
# 9995        9995    0.726  2012      0.002240
# 9996        9996    0.834  1943      0.944000
# 9997        9997    0.902  1975      0.682000
# 9998        9998    0.896  1995      0.187000
# 9999        9999    0.218  2015      0.005540
#
#                                               artists  danceability  \
# 0                                        ['Parmalee']         0.551
# 1                                           ['JAY-Z']         0.494
# 2                                        ['Sam Hunt']         0.590
# 3                                     ['Iron Maiden']         0.340
# ...

# %%
data_language_df["language_2"].value_counts("en")*100
# Out:
# UNKNOWN    53.61
# en         19.96
# it          3.24
# af          2.00
# pt          1.90
# es          1.58
# fr          1.57
# de          1.52
# da          1.26
# nb          1.22
# ca          0.87
# ru          0.83
# ro          0.80
# nl          0.76
# ha          0.65
# eo          0.59
# la          0.56
# id          0.55
# haw         0.53
# nso         0.47
# zh          0.42
# tl          0.39
# el          0.37
# sl          0.32
# sv          0.31
# et          0.31
# ceb         0.30
# sk          0.29
# cs          0.22
# fi          0.22
# st          0.21
# lt          0.20
# hr          0.16
# uk          0.15
# so          0.14
# tlh         0.12
# ve          0.12
# sw          0.11
# eu          0.10
# tr          0.10
# hu          0.09
# lv          0.09
# ja          0.09
# pl          0.09
# cy          0.08
# tn          0.08
# sq          0.07
# ts          0.06
# th          0.06
# is          0.04
# sr          0.04
# ss          0.04
# ...
